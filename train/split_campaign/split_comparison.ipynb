# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_rows', 100)
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
plt.style.use(plt.style.available[24])
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=16)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=12)    # fontsize of the xtick labels
plt.rc('ytick', labelsize=12)     # fontsize of the ytick labels (also applies to colorbar)
plt.rc('legend', fontsize=14)    # legend fontsize
plt.rc('figure', titlesize=20)   # fontsize of the figure title
plt.rc('lines', linewidth=2)     # line width
plt.rc('figure', figsize=(6, 5)) # figure size
plt.rc('axes', axisbelow=True)

# %%
df_nn_data = pd.read_csv('results/NN_data_split.csv')
df_poly_data1 = pd.read_csv('results/POLY_data_split_deg1.csv')
df_poly_data2 = pd.read_csv('results/POLY_data_split_deg2.csv')
df_poly_data3 = pd.read_csv('results/POLY_data_split_deg3.csv')
df_svgp_data = pd.read_csv('results/SVGP_data_split.csv')

# %%
fig, ax = plt.subplots(ncols=1, figsize=(5, 4))
ax.set_xlabel('Training Points [$10^6$]')
ax.set_ylabel('MAPE [%]')

color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
print(color_cycle)
#ax.plot(df_poly_data1['points']/1e6, (df_poly_data1['max mape corrected'] + df_poly_data1['tot mape corrected'] + df_poly_data1['avg mape corrected'])/3, label='POLY_deg1')
ax.plot(df_poly_data2['points']/1e6, (df_poly_data2['max mape corrected'] + df_poly_data2['tot mape corrected'] + df_poly_data2['avg mape corrected'])/3, label='POLY_deg2', linestyle='dashed', color=color_cycle[0])
ax.plot(df_poly_data3['points']/1e6, (df_poly_data3['max mape corrected'] + df_poly_data3['tot mape corrected'] + df_poly_data3['avg mape corrected'])/3, label='POLY_deg3', color=color_cycle[0])
ax.plot(df_svgp_data['points']/1e6, (df_svgp_data['max mape corrected'] + df_svgp_data['tot mape corrected'] + df_svgp_data['avg mape corrected'])/3, label='SVGP', color=color_cycle[1])
ax.plot(df_nn_data['points']/1e6, (df_nn_data['max mape corrected'] + df_nn_data['tot mape corrected'] + df_nn_data['avg mape corrected'])/3, label='NN', color=color_cycle[2])
# ax2 = ax[0].twinx()
# ax2.plot(df_poly_data1['points']/1e6, df_poly_data1['time']/60, linestyle='dashed', label='POLY Time')
# ax2.plot(df_svgp_data['points']/1e6, df_svgp_data['time']/60, linestyle='dashed', label='SVGP Time')
# ax2.plot(df_nn_data['points']/1e6, df_nn_data['time']/60, linestyle='dashed', label='NN Time')
# ax2.set_ylabel('Training Time (min)')
# ax2.grid(False)
# ax2.set_yscale('log')
# ax2.set_frame_on(False)
#ax[0].text(1.15, 16, '(a)', fontsize=16)
#ax[0].set_ylim(0, 17)

ax.grid(True)
ax.legend()
fig.subplots_adjust(wspace=0.5)
fig.savefig('plots/split_campaign_train.eps', format='eps', bbox_inches='tight')
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
